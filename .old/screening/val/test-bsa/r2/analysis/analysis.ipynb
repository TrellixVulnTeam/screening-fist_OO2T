# %%
import pandas as pd

exceptions = pd.read_csv('../data/cpd_Exceptions.csv')
exceptions.head()
# Out:
#   Source Plate Name  Source Plate Barcode Source Plate Type Source Well  \
# 0         Source[2]                   NaN       384LDV_DMSO          H7
# 1         Source[2]                   NaN       384LDV_DMSO          H7
# 2         Source[2]                   NaN       384LDV_DMSO          H7
# 3         Source[2]                   NaN       384LDV_DMSO          H7
# 4         Source[2]                   NaN       384LDV_DMSO          H7
#
#   Destination Plate Name  Destination Plate Barcode Destination Plate Type  \
# 0         Destination[2]                        NaN             384PP_Dest
# 1         Destination[2]                        NaN             384PP_Dest
# 2         Destination[2]                        NaN             384PP_Dest
# 3         Destination[2]                        NaN             384PP_Dest
# 4         Destination[2]                        NaN             384PP_Dest
#
#   Destination Well  Destination Well X Offset  Destination Well Y Offset  \
# ...

# %%
picklist = pd.read_csv('../design/cpd-src-picklist.csv', index_col=0)
picklist.head()
# Out:
#   SrcPlate SrcWell Destination Plate Name DestWell  Transfer Volume /nl
# 0     src1      G1         dest-bsa-blank       A2                  5.0
# 1     src1      G1         dest-bsa-blank       A3                 35.0
# 2     src1      G1         dest-bsa-blank       A4                117.5
# 3     src1      G1         dest-bsa-blank       A5                280.0
# 4     src1      G1         dest-bsa-blank       A6                547.5

# %%
src = pd.read_csv('../design/src_layout.csv')
src.head()
# Out:
#                          Item Name CatalogNumber Rack Number Plate Location  \
# 0                      Bezafibrate         S4159    L1300-10             e6
# 1                       Pranlukast         S1829    L1300-04             c9
# 2                     Cyclandelate         S4189    L1300-10             f9
# 3                    norethindrone         S4040    L1300-09             e8
# 4  Esomeprazole magnesium (Nexium)         S1743    L1300-04             a4
#
#        Src Wells
# 0   ['G1', 'G2']
# 1   ['G3', 'G4']
# 2   ['G5', 'G6']
# 3   ['G7', 'G8']
# 4  ['G9', 'G10']
