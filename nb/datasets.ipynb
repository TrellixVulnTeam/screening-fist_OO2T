# %%
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from rdkit.Chem import AllChem as Chem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.info')     

paths = ['../model/data/o3f.train.csv',
         '../model/data/o3f.test.csv',
         '../model/data/screening-data.train.csv',
         '../model/data/screening-data.test.csv',
         ]
properties =   ['CalcLabuteASA',
                'CalcTPSA',
                'CalcExactMolWt',
                'CalcNumLipinskiHBD',
                'CalcNumLipinskiHBA',
                'CalcNumHBD',
                'CalcNumHBA',
                'CalcNumRotatableBonds',
                'CalcNumRings',
                'CalcNumAromaticRings',
                'CalcNumSaturatedRings',
                'CalcNumHeterocycles',
                'CalcNumAromaticHeterocycles',
                'CalcNumAromaticCarbocycles',
                'CalcNumSaturatedHeterocycles',
                'CalcNumSaturatedCarbocycles',
                'CalcNumAliphaticRings',
                'CalcNumAliphaticHeterocycles',
                'CalcNumAliphaticCarbocycles',
                'CalcNumHeteroatoms',
                'CalcNumAmideBonds',
                'CalcFractionCSP3',
                ]

def calc_chemprops(mol):
    fn = lambda fn, mol : Chem.__dict__[fn](mol)
    props = {}
    for i in properties:
        props[i] = fn(i, mol)
    return props

def make_report(path):
    df = pd.read_csv(path)
    sequences = df['seq']
    usequences = df['seq'].unique()
    usmiles = df['smiles'].unique()
    hits = df['hit']
    mols = [Chem.MolFromSmiles(i) for i in usmiles]
    chemprops = {}
    for i, j in tqdm(zip(usmiles, mols), total=len(mols)):
        chemprops[i] = calc_chemprops(j)
    chemprops = pd.DataFrame(chemprops).T
    
    
x = make_report(paths[-1])
x
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 3164.78it/s]
#                                                    CalcLabuteASA CalcTPSA  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...     198.96119   124.99
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...    176.079304    38.13
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...    364.573579   186.15
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...    150.126304    71.53
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...    169.158158   116.25
# ...                                                          ...      ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|           107.336613    24.39
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...    234.551415   162.16
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|     113.899853   111.56
# NCCCCCC(O)=O                                           54.859608    63.32
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...     194.25608    69.59
#
#                                                    CalcExactMolWt  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...     499.169844
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...     417.137468
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...     868.566041
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...     357.114712
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...     405.189986
# ...                                                           ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|            256.080097
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...     558.222683
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|      290.033731
# NCCCCCC(O)=O                                           131.094629
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...     443.209658
#
#                                                    CalcMolFormula  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...    C23H33NO7S2
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...   C22H25Cl2N3O
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...    C46H80N2O13
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...    C18H19N3O3S
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...     C20H27N3O6
# ...                                                           ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|           C12H17ClN2S
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...     C29H30N6O6
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|   C10H12Cl2N4O2
# NCCCCCC(O)=O                                             C6H13NO2
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...      C28H29NO4
#
#                                                    CalcNumLipinskiHBD  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                  2
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                  0
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                  4
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                  1
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                  2
# ...                                                               ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                         1
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                  2
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                   5
# NCCCCCC(O)=O                                                        3
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                  1
#
#                                                    CalcNumLipinskiHBA  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                  8
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                  4
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                 15
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                  6
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                  9
# ...                                                               ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                         2
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                 12
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                   6
# NCCCCCC(O)=O                                                        3
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                  5
#
#                                                    CalcNumHBD CalcNumHBA  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...          2          7
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...          0          4
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...          4         15
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...          1          6
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...          2          6
# ...                                                       ...        ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                 1          3
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...          2         11
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|           4          3
# NCCCCCC(O)=O                                                2          2
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...          1          4
#
#                                                    CalcNumRotatableBonds  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                    11
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                     3
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                    12
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                     7
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                     9
# ...                                                                  ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                            1
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                    10
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                      2
# NCCCCCC(O)=O                                                           5
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                     7
#
#                                                    CalcNumRings  ...  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...            2  ...
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...            4  ...
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...            4  ...
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...            3  ...
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...            2  ...
# ...                                                         ...  ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                   2  ...
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...            5  ...
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|             1  ...
# NCCCCCC(O)=O                                                  0  ...
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...            4  ...
#
#                                                    CalcNumAromaticHeterocycles  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                           0
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                           1
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                           0
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                           1
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                           0
# ...                                                                        ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                                  0
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                           3
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                            0
# NCCCCCC(O)=O                                                                 0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                           0
#
#                                                    CalcNumAromaticCarbocycles  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                          2
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                          2
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                          0
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                          1
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                          1
# ...                                                                       ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                                 1
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                          2
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                           1
# NCCCCCC(O)=O                                                                0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                          4
#
#                                                    CalcNumSaturatedHeterocycles  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                            0
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                            1
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                            3
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                            1
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                            1
# ...                                                                         ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                                   0
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                            0
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                             0
# NCCCCCC(O)=O                                                                  0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                            0
#
#                                                    CalcNumSaturatedCarbocycles  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                           0
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                           0
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                           0
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                           0
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                           0
# ...                                                                        ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                                  0
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                           0
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                            0
# NCCCCCC(O)=O                                                                 0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                           0
#
#                                                    CalcNumAliphaticRings  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                     0
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                     1
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                     4
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                     1
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                     1
# ...                                                                  ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                            1
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                     0
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                      0
# NCCCCCC(O)=O                                                           0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                     0
#
#                                                    CalcNumAliphaticHeterocycles  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                            0
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                            1
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                            4
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                            1
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                            1
# ...                                                                         ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                                   1
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                            0
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                             0
# NCCCCCC(O)=O                                                                  0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                            0
#
#                                                    CalcNumAliphaticCarbocycles  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                           0
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                           0
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                           0
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                           0
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                           0
# ...                                                                        ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                                  0
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                           0
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                            0
# NCCCCCC(O)=O                                                                 0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                           0
#
#                                                    CalcNumHeteroatoms  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                 10
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                  6
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                 15
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                  7
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                  9
# ...                                                               ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                         4
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                 12
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                   8
# NCCCCCC(O)=O                                                        3
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                  5
#
#                                                    CalcNumAmideBonds  \
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...                 1
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...                 0
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...                 0
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...                 2
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...                 3
# ...                                                              ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                        0
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...                 0
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|                  0
# NCCCCCC(O)=O                                                       0
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...                 0
#
#                                                    CalcFractionCSP3
# CC1=CC=C(C=C1)S([O-])(=O)=O.CCOCC(O)COC1=CC=C(N...         0.434783
# Cl.CN1CCCC(CC1)N1N=C(CC2=CC=C(Cl)C=C2)C2=CC=CC=...         0.363636
# CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2...         0.869565
# CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1 |...         0.277778
# CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1[C...              0.5
# ...                                                             ...
# Cl.CC1=CC=CC(C)=C1NC1=NCCCS1 |c:3,6,t:1,10|                0.416667
# CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N...         0.310345
# CC(O)=O.NC(=N)N\N=C\C1=C(Cl)C=CC=C1Cl |c:9,12,14|               0.1
# NCCCCCC(O)=O                                               0.833333
# OC1=C(C=C2C=CC=CC2=C1)C([O-])=O.C[N+](C)(CCOC1=...         0.178571
#
# [600 rows x 23 columns]
