# %% [markdown]
# ## 05 - 1YQP - 27th April 2022
#
# storage:
# 1yqp - 75-81 - 8000 µl
#
#  tubes:
#  69, 70, 71, 72, 73, 74

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

import uv

data = uv.P450('../uv-vis/20220427-05-1yqp-predil.csv')
uv.plot_traces(data.df)

# %%
data.concs(95)
# Out:
# blank                            0.000000
# bm3-1yqp-heme-10in1000-tube78    6.452486
# bm3-1yqp-heme-10in1000-tube79    8.694857
# bm3-1yqp-heme-10in1000-tube80    7.260259
# bm3-1yqp-heme-10in1000-tube81    5.947180
# bm3-1yqp-heme-10in1000-pooled    7.303942
# Name: P450 conc/uM, dtype: float64

# %%
minvol = 384 * 15 * 40 / 1000
print(f'Min vol to fill plates: {minvol} ml')
print(f'with 20 ml saftey: {minvol + 20} ml')
# Out:
# Min vol to fill plates: 230.4 ml
# with 20 ml saftey: 250.4 ml

# %%
def v1(c1,v2,c2):
    return (v2 * c2) / c1

c1 = 7.303942 / (20/100)
print(f'protein stock conc: {c1} µM')
v2 =  minvol + 20
print(f'{v1(c1, v2, 20)} µl protein in {v2} ml buffer')
# Out:
# protein stock conc: 36.519709999999996 µM
# 137.13142848067525 µl protein in 250.4 ml buffer

# %%
data2 = uv.P450('../uv-vis/20220427-05-1yqp-post-dil.csv')
uv.plot_traces(data2.df)
print(data.concs(95))
# Out:
# blank                            0.000000
# bm3-1yqp-heme-10in1000-tube78    6.452486
# bm3-1yqp-heme-10in1000-tube79    8.694857
# bm3-1yqp-heme-10in1000-tube80    7.260259
# bm3-1yqp-heme-10in1000-tube81    5.947180
# bm3-1yqp-heme-10in1000-pooled    7.303942
# Name: P450 conc/uM, dtype: float64

# %% [markdown]
# Dispensed, spun and ran that

# %%
# Out:
# lab.ipynb
