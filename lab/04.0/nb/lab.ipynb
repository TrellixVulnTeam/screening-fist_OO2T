# %% [markdown]
# ## 04 - 1YQO - 26th April 2022
#
# storage:
#  1yqo 67-74 - 3500µl
#
#  tubes:
#  69, 70, 71, 72, 73, 74

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

import uv

data = uv.P450('../uv-vis/20220426-exp04-1yqp-predil.csv')
uv.plot_traces(data.df)

# %%
data.concs(95)
# Out:
# baseline                     0.000000
# bm3-1yqo-20in1000-tube69    11.601869
# bm3-1yqo-20in1000-tube70    11.721786
# bm3-1yqo-20in1000-tube71    12.083936
# bm3-1yqo-20in1000-tube72    10.832418
# bm3-1yqo-20in1000-tube73    11.223542
# bm3-1yqo-20in1000-tube74    12.942264
# bm3-1yqo-10in1000-pooled     8.810531
# Name: P450 conc/uM, dtype: float64

# %%
minvol = 384 * 15 * 40 / 1000
print(f'Min vol to fill plates: {minvol} ml')
print(f'with 20 ml saftey: {minvol + 20} ml')
# Out:
# Min vol to fill plates: 230.4 ml
# with 20 ml saftey: 250.4 ml

# %%
def v1(c1,v2,c2):
    return (v2 * c2) / c1

c1 = 8.810531 / (20/100)
print(f'protein stock conc: {c1} µM')
v2 =  minvol + 20
print(f'{v1(c1, v2, 20)} µl protein in {v2} ml buffer')
# Out:
# protein stock conc: 44.052654999999994 µM
# 113.68213788703542 µl protein in 250.4 ml buffer
